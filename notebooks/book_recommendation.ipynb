# %% [markdown]
# ### Book Recommendation System

# %%
#importing libaries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
#Data Reading

books = pd.read_csv("data/Books.csv")
ratings = pd.read_csv("data/Ratings.csv")
users = pd.read_csv("data/Users.csv")
# Out:
# C:\Users\Ayush Gandhi\AppData\Local\Temp\ipykernel_20032\3229398344.py:3: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv("data/Books.csv")

# %%
books
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
ratings
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
users
# Out:
#         User-ID                            Location   Age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %%
#knowing shape of every features

print(f"books:{books.shape}")
print(f"users{users.shape}")
print(f"ratings:{ratings.shape}")
# Out:
# books:(271360, 8)
# users(278858, 3)
# ratings:(1149780, 3)

# %%
#Explore columns data in every dataset

dataframe = [books, users, ratings]

# %%
for i in dataframe:
    print (i.columns)
    print (i.shape)
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')
# (271360, 8)
# Index(['User-ID', 'Location', 'Age'], dtype='object')
# (278858, 3)
# Index(['User-ID', 'ISBN', 'Book-Rating'], dtype='object')
# (1149780, 3)

# %% [markdown]
# > ISBN connects Books & Ratings
#
# > User-ID connects Users & Ratings

# %%
#Let's explore books dataset & keep the necessary columns

books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %% [markdown]
# - ISBN connects ratings for a while, so we need to keep it.
# - Book-Title, Book-Author, Year-of-publication are important columns along with publisher.
# - There are 3 image URL links we can keep only 1, so we can keep the large one.
#
# > We will rename all columns for better understanding.

# %%
books = books[["ISBN", "Book-Title", "Book-Author", "Year-Of-Publication", "Publisher", "Image-URL-L"]]

# %%
#Let's rename it.

books = books.rename(columns= {
    "Book-Title" : "book",
    "Book-Author" : "author",
    "Year-Of-Publication" : "year",
    "Publisher" : "publisher",
    "Image-URL-L" : "image_link"
})

# %%
books
# Out:
#               ISBN                                               book  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                       author  year  \
# 0         Mark P. O. Morford  2002
# 1       Richard Bruce Wright  2001
# ...

# %%
#Let's explore null & Missing values
books.isnull().sum()
# Out:
# ISBN          0
# book          0
# author        2
# year          0
# publisher     2
# image_link    3
# dtype: int64

# %%
#Let's explore duplicate values

books.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #There are just at most 3 null values with no duplicates, we can handle it afterwards

# %%
#Let's explore ratings datset
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
#Everything seems fine, just rename book-rating to rating

ratings = ratings.rename({
    "Book-Rating" : "rating"
}
)

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
ratings.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #There are no null or duplicated values in the column

# %%
#Let's explore the user dataset

users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
users.duplicated().sum()
# Out:
# 0

# %%
#There are no duplicate values but many null values in age column, but this column can be drop as it can seems less significance to contribution

users = users[["User-ID", "Location"]]

# %%
users = users.rename({
    "Location" : "location"
})
