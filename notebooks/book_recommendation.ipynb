# %% [markdown]
# ### Book Recommendation System

# %%
#importing libaries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
#Data Reading

books = pd.read_csv("data/Books.csv")
ratings = pd.read_csv("data/Ratings.csv")
users = pd.read_csv("data/Users.csv")
# Out:
# C:\Users\Ayush Gandhi\AppData\Local\Temp\ipykernel_16980\3229398344.py:3: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv("data/Books.csv")

# %%
books
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
ratings
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
users
# Out:
#         User-ID                            Location   Age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %%
#knowing shape of every features

print(f"books:{books.shape}")
print(f"users{users.shape}")
print(f"ratings:{ratings.shape}")
# Out:
# books:(271360, 8)
# users(278858, 3)
# ratings:(1149780, 3)

# %%
#Explore columns data in every dataset

dataframe = [books, users, ratings]

# %%
for i in dataframe:
    print (i.columns)
    print (i.shape)
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')
# (271360, 8)
# Index(['User-ID', 'Location', 'Age'], dtype='object')
# (278858, 3)
# Index(['User-ID', 'ISBN', 'Book-Rating'], dtype='object')
# (1149780, 3)

# %% [markdown]
# > ISBN connects Books & Ratings
#
# > User-ID connects Users & Ratings

# %%
#Let's explore books dataset & keep the necessary columns

books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %% [markdown]
# - ISBN connects ratings for a while, so we need to keep it.
# - Book-Title, Book-Author, Year-of-publication are important columns along with publisher.
# - There are 3 image URL links we can keep only 1, so we can keep the large one.
#
# > We will rename all columns for better understanding.

# %%
books = books[["ISBN", "Book-Title", "Book-Author", "Year-Of-Publication", "Publisher", "Image-URL-L"]]

# %%
#Let's rename it.

books = books.rename(columns= {
    "Book-Title" : "book",
    "Book-Author" : "author",
    "Year-Of-Publication" : "year",
    "Publisher" : "publisher",
    "Image-URL-L" : "image_link"
})

# %%
books
# Out:
#               ISBN                                               book  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                       author  year  \
# 0         Mark P. O. Morford  2002
# 1       Richard Bruce Wright  2001
# ...

# %%
#Let's explore null & Missing values
books.isnull().sum()
# Out:
# ISBN          0
# book          0
# author        2
# year          0
# publisher     2
# image_link    3
# dtype: int64

# %%
#Let's explore duplicate values

books.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #There are just at most 3 null values with no duplicates, we can handle it afterwards

# %%
#Let's explore ratings datset
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
#Everything seems fine, just rename book-rating to rating

ratings = ratings.rename(columns = {
    "Book-Rating" : "rating"
}
)

# %%
ratings
# Out:
#          User-ID         ISBN  rating
# 0         276725   034545104X       0
# 1         276726   0155061224       5
# 2         276727   0446520802       0
# 3         276729   052165615X       3
# 4         276729   0521795028       6
# ...          ...          ...     ...
# 1149775   276704   1563526298       9
# 1149776   276706   0679447156       0
# 1149777   276709   0515107662      10
# 1149778   276721   0590442449      10
# 1149779   276723  05162443314       8
#
# [1149780 rows x 3 columns]

# %%
ratings.isnull().sum()
# Out:
# User-ID    0
# ISBN       0
# rating     0
# dtype: int64

# %%
ratings.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #There are no null or duplicated values in the column

# %%
#Let's explore the user dataset

users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
users.duplicated().sum()
# Out:
# 0

# %%
#There are no duplicate values but many null values in age column, but this column can be drop as it can seems less significance to contribution

users = users[["User-ID", "Location"]]

# %%
users = users.rename({
    "Location" : "location"
})

# %% [markdown]
# We are gonna create book recommendation system on 3 basis:
# > Popularity based
#
# > Content based
#
# > Collabarative based

# %% [markdown]
# ### Popularity based
#
# This system is based on most popular books which are highly rated among them

# %%
#For that we can consider the books which have been rated by more then 200 users with their highest popular rating 

ratings_with_name = ratings.merge(books, on="ISBN")

# %%
ratings_with_name.head()
# Out:
#    User-ID        ISBN  rating                  book      author  year  \
# 0   276725  034545104X       0  Flesh Tones: A Novel  M. J. Rose  2002
# 1     2313  034545104X       5  Flesh Tones: A Novel  M. J. Rose  2002
# 2     6543  034545104X       0  Flesh Tones: A Novel  M. J. Rose  2002
# 3     8680  034545104X       5  Flesh Tones: A Novel  M. J. Rose  2002
# 4    10314  034545104X       9  Flesh Tones: A Novel  M. J. Rose  2002
#
#           publisher                                         image_link
# 0  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...
# 1  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...
# 2  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...
# 3  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...
# 4  Ballantine Books  http://images.amazon.com/images/P/034545104X.0...

# %%
ratings_with_name.shape
# Out:
# (1031136, 8)

# %%
#Book with more then 200 ratings

num_rating_df = ratings_with_name.groupby("book").count()[["ISBN"]]

# %%
num_rating_df.rename(columns={
    "ISBN" : "no_ratings"
}, inplace = True)

# %%
num_rating_df
# Out:
#                                                     no_ratings
# book
#  A Light in the Storm: The Civil War Diary of A...           4
#  Always Have Popsicles                                       1
#  Apple Magic (The Collector's series)                        1
#  Ask Lily (Young Women of Faith: Lily Series, B...           1
#  Beyond IBM: Leadership Marketing and Finance f...           1
# ...                                                        ...
# Ã?Â?lpiraten.                                                2
# Ã?Â?rger mit Produkt X. Roman.                               4
# Ã?Â?sterlich leben.                                          1
# Ã?Â?stlich der Berge.                                        3
# Ã?Â?thique en toc                                            2
#
# [241071 rows x 1 columns]

# %%
avg_rating_df = ratings_with_name.groupby('book')["rating"].mean()

# %%
avg_rating_df
# Out:
# book
#  A Light in the Storm: The Civil War Diary of Amelia Martin, Fenwick Island, Delaware, 1861 (Dear America)    2.250000
#  Always Have Popsicles                                                                                        0.000000
#  Apple Magic (The Collector's series)                                                                         0.000000
#  Ask Lily (Young Women of Faith: Lily Series, Book 5)                                                         8.000000
#  Beyond IBM: Leadership Marketing and Finance for the 1990s                                                   0.000000
#                                                                                                                 ...
# Ã?Â?lpiraten.                                                                                                 0.000000
# Ã?Â?rger mit Produkt X. Roman.                                                                                5.250000
# ...

# %%
popular_df = num_rating_df.merge(avg_rating_df, on = "book")

# %%
popular_df
# Out:
#                                                     no_ratings    rating
# book
#  A Light in the Storm: The Civil War Diary of A...           4  2.250000
#  Always Have Popsicles                                       1  0.000000
#  Apple Magic (The Collector's series)                        1  0.000000
#  Ask Lily (Young Women of Faith: Lily Series, B...           1  8.000000
#  Beyond IBM: Leadership Marketing and Finance f...           1  0.000000
# ...                                                        ...       ...
# Ã?Â?lpiraten.                                                2  0.000000
# Ã?Â?rger mit Produkt X. Roman.                               4  5.250000
# Ã?Â?sterlich leben.                                          1  7.000000
# Ã?Â?stlich der Berge.                                        3  2.666667
# Ã?Â?thique en toc                                            2  4.000000
#
# [241071 rows x 2 columns]

# %% [markdown]
# Now for the popularity recommendation system, we select the books which has at least got more then 200 ratings, so that it can be unbias to judge them, we can select top 20 books based on that.

# %%
popular_df = popular_df[popular_df["no_ratings"]>200].sort_values("rating", ascending= False).head(20)

# %%
popular_df.merge
# Out:
#                                                     no_ratings    rating
# book
# Harry Potter and the Prisoner of Azkaban (Book 3)          428  5.852804
# Harry Potter and the Goblet of Fire (Book 4)               387  5.824289
# Harry Potter and the Sorcerer's Stone (Book 1)             278  5.737410
# Harry Potter and the Order of the Phoenix (Book 5)         347  5.501441
# Ender's Game (Ender Wiggins Saga (Paperback))              249  5.409639
# Harry Potter and the Chamber of Secrets (Book 2)           556  5.183453
# The Hobbit : The Enchanting Prelude to The Lord...         281  5.007117
# The Fellowship of the Ring (The Lord of the Rin...         368  4.948370
# Harry Potter and the Sorcerer's Stone (Harry Po...         575  4.895652
# The Two Towers (The Lord of the Rings, Part 2)             260  4.880769
# To Kill a Mockingbird                                      510  4.700000
# The Da Vinci Code                                          898  4.642539
# ...

# %%
popular_df = popular_df.merge(books, on = "book").drop_duplicates("book")[["book", "author", "year", "image_link"]]

# %%
#top20 books
popular_df
# Out:
#                                                  book               author  \
# 0   Harry Potter and the Prisoner of Azkaban (Book 3)        J. K. Rowling
# 3        Harry Potter and the Goblet of Fire (Book 4)        J. K. Rowling
# 5      Harry Potter and the Sorcerer's Stone (Book 1)        J. K. Rowling
# 9   Harry Potter and the Order of the Phoenix (Boo...        J. K. Rowling
# 13      Ender's Game (Ender Wiggins Saga (Paperback))     Orson Scott Card
# 17   Harry Potter and the Chamber of Secrets (Book 2)        J. K. Rowling
# 20  The Hobbit : The Enchanting Prelude to The Lor...       J.R.R. TOLKIEN
# 21  The Fellowship of the Ring (The Lord of the Ri...       J.R.R. TOLKIEN
# 30  Harry Potter and the Sorcerer's Stone (Harry P...        J. K. Rowling
# 32     The Two Towers (The Lord of the Rings, Part 2)       J.R.R. TOLKIEN
# 43                              To Kill a Mockingbird           Harper Lee
# ...

# %% [markdown]
# ### Collaborative Filtering Based recommendation System

# %% [markdown]
# We will consider the two factor to consider this recommendation system.
#
# User has at least rated more then 200 books. --> So that it is an experience user.
#
# At least 50 time that particular book has been rated --> To get similarity between two users

# %%
x = ratings_with_name.groupby("User-ID").count()["book"] > 200

# %%
knowledge_users = x[x].index

# %%
filtered_rating = ratings_with_name[ratings_with_name["User-ID"].isin(knowledge_users)]

# %%
y = filtered_rating.groupby("book").count()["rating"] >=50

# %%
famous_books = y[y].index

# %%
final_ratings = filtered_rating[filtered_rating["book"].isin(famous_books)]

# %%
pt = final_ratings.pivot_table(index="book", columns="User-ID", values = "rating")

# %%
pt.fillna(0, inplace = True)

# %%
pt.shape
# Out:
# (706, 810)

# %%
from scipy.sparse import csr_matrix

# %%
book_sparse = csr_matrix(pt)

# %%
from sklearn.neighbors import NearestNeighbors

model = NearestNeighbors(algorithm="brute")

# %%
model.fit(book_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
distance, suggestion = model.kneighbors(pt.iloc[237, :].values.reshape(1, -1), n_neighbors=6)

# %%
distance
# Out:
# array([[ 0.        , 29.30870178, 30.01666204, 30.41381265, 30.47950131,
#         30.87069808]])

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_score = cosine_similarity(pt)

# %%
similarity_score[0]
# Out:
# array([1.        , 0.10255025, 0.01220856, 0.        , 0.05367224,
#        0.02774901, 0.08216491, 0.13732869, 0.03261686, 0.03667591,
#        0.02322418, 0.06766487, 0.02083978, 0.09673735, 0.13388865,
#        0.08303112, 0.11153543, 0.05100411, 0.02517784, 0.11706383,
#        0.        , 0.14333793, 0.07847534, 0.06150451, 0.08723968,
#        0.        , 0.07009814, 0.13658681, 0.07600328, 0.12167134,
#        0.00768046, 0.01473221, 0.        , 0.07965814, 0.04522617,
#        0.01556271, 0.09495938, 0.0182307 , 0.02610465, 0.07984012,
#        0.11679969, 0.0569124 , 0.08354155, 0.08471898, 0.08785938,
#        0.05491435, 0.0548505 , 0.27026514, 0.09779123, 0.06016046,
#        0.08958835, 0.06748675, 0.        , 0.04468098, 0.01920872,
#        0.        , 0.05629067, 0.00557964, 0.07877059, 0.05219479,
#        0.18908177, 0.        , 0.01240656, 0.02984572, 0.04279502,
#        0.12680125, 0.16566735, 0.        , 0.13357242, 0.06615478,
# ...

# %%
def recommend(book_name):
    #Index fetch
    index = np.where(pt.index == book_name)[0][0]
    similar_items = sorted(list(enumerate(similarity_score[index])), key = lambda x:x[1], reverse = True) [1:6]
    
    for i in similar_items:
        print(pt.index[i[0]])

# %%
recommend("Message in a Bottle")
# Out:
# Nights in Rodanthe
# The Mulberry Tree
# A Walk to Remember
# River's End
# Nightmares &amp; Dreamscapes

# %%
books_name = pt.index
